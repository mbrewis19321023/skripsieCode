# %%
# begin importing of standard modules
import re
import random
import os
import tkinter as tk
from tkinter import messagebox
import pandas as pd
import pprint as pp
import sys
# end importing of standard modules

##############################################################################################################################################################################################################################

# begin setting of home path variable and adding data directory to path import list
if 'sani.ipynb' or 'sani.py' in os.listdir():
    home = os.getcwd()     
sys.path.append(os.path.join(home, 'data')) #This will add the data folder to the path variable so modules can be imported 
# end setting of home path variable and adding data directory to path import list

##############################################################################################################################################################################################################################

# begin import of created modules
try:   
    import ds
    import mypath
    input('''Success!!!

Press any key to exit...''')
except ModuleNotFoundError:
    input('''Before this program can be run, sani.py must be run first.
This will ensure that the needed python modules are created in the data directory!

Please run sani.py and try again

Press any key to exit...''')
# begin import of created modules

##############################################################################################################################################################################################################################
# Out:
# Success!!!
#
# Press any key to exit...y

# %%
# begin importing and creation of a data frame
df = pd.DataFrame(ds.dictStd.items())
df.rename(columns={0: "std", 1: "hsh"}, inplace = True)
# end importing and creation of a data frame

##############################################################################################################################################################################################################################

# begin vreation of the drivers path column in dataDrame
df['DriversPath'] = 'NaN'
# end vreation of the drivers path column in dataDrame

##############################################################################################################################################################################################################################

# %%
validHash = re.compile(r'#\d{0,3}')

# %%
# def findDriver(pathOfFile):
#     import ipdb; ipdb.set_trace()
#     os.chdir(pathOfFile)
#     if 'Drivers' in os.listdir():
#         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#         os.chdir(mypath.repos)
#     else:
#         for i in os.listdir():
#             if os.path.isdir(i):
#                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#                 findDriver(pathOfFile)
#             else:
#                 os.chdir(mypath.repos)

# %%
def findDrivers2(filepath):
#     import ipdb; ipdb.set_trace()
    for i in os.listdir(filepath):
        newPath = os.path.join(filepath , i)
        if i in ['.git','.settings','Core','Debug','.metadata']:
            pass
        elif i == 'Drivers':
            df.loc[df['hsh'] == validHash.findall(newPath)[0], ['DriversPath']] = newPath
        elif os.path.isdir(newPath) == False:
            pass
        elif os.path.isdir(newPath) and i != 'Drivers':                   
            findDrivers2(newPath)

# %%
os.chdir(mypath.repos)
os.getcwd()
os.listdir()
# findDriver(mypath.repos)
filepath = mypath.repos
findDrivers2(filepath)
# Out:
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\.cproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\.git
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\.mxproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\.project
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\.settings
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\22046364.txt
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\Core
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\Debug
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\Drivers
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\E_Design Debug.launch
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\E_Design.ioc
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\README.md
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\STM32F446RETX_FLASH.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\STM32F446RETX_RAM.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\Task 1.docx
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\Task 1.pdf
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\.cproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\.git
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\.gitignore
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\.mxproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\.project
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\.settings
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\22252975.txt
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\Core
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\Debug
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\Drivers
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\edesign_2020_22252975 Debug.launch
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\edesign_2020_22252975.ioc
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\README.md
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\STM32F446RETX_FLASH.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\STM32F446RETX_RAM.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#2
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#2\21957029.txt
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\.git
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\22127011.txt
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\.cproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\.mxproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\.project
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\.settings
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\Core
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\Debug
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\Drivers
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\First_Project Debug.launch
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\First_Project.ioc
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\STM32F446RETX_FLASH.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\STM32F446RETX_RAM.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\README.md
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\.git
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\.metadata
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\22074376.txt
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\.cproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\.mxproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\.project
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\.settings
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\Core
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\Da-Bug Debug.launch
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\Da-Bug.ioc
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\Debug
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\Drivers
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\STM32F446RETX_FLASH.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\STM32F446RETX_RAM.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\README.md
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\RemoteSystemsTempFiles
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\RemoteSystemsTempFiles\.project
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\.cproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\.git
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\.mxproject
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\.project
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\.settings
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\22218521.txt
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\Core
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\Debug
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\Drivers
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\eDesign_SK_Mbatha_22218521 Debug.cfg
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\eDesign_SK_Mbatha_22218521 Debug.launch
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\eDesign_SK_Mbatha_22218521.ioc
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\STM32F446RETX_FLASH.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\STM32F446RETX_RAM.ld
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\20416318.txt
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\Luke
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\Luke\I
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\Luke\I\am
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\Luke\I\am\your
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\Luke\I\am\your\father
# C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\Luke\I\am\your\father\Drivers

# %%
# for i in range(6):
#     import ipdb; ipdb.set_trace()
#     print(i)

# %%
# os.chdir(os.path.join(mypath.repos , str('#1')))
# for i in os.listdir():
#     if os.path.isdir(i):
#         print('yes')
# os.listdir()

# %%
pd.set_option('max_colwidth', 200)

# %%
df
# Out:
#         std hsh  \
# 0  20416318  #6
# 1  21957029  #2
# 2  22046364  #0
# 3  22074376  #4
# 4  22127011  #3
# 5  22218521  #5
# 6  22252975  #1
#
#                                                                      DriversPath
# 0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#6\Luke\I\am\your\father\Drivers
# 1                                                                            NaN
# 2                        C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0\Drivers
# 3                 C:\Users\1995m\Desktop\skripsieCode\stdRepos\#4\Da-Bug\Drivers
# 4          C:\Users\1995m\Desktop\skripsieCode\stdRepos\#3\First_Project\Drivers
# 5                        C:\Users\1995m\Desktop\skripsieCode\stdRepos\#5\Drivers
# 6                        C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1\Drivers
