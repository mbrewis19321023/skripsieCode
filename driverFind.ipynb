# %%
# begin importing of standard modules
import re
import random
import os
import tkinter as tk
from tkinter import messagebox
import pandas as pd
import pprint as pp
import sys
# end importing of standard modules

##############################################################################################################################################################################################################################

# begin setting of home path variable and adding data directory to path import list
if 'sani.ipynb' or 'sani.py' in os.listdir():
    home = os.getcwd()     
sys.path.append(os.path.join(home, 'data')) #This will add the data folder to the path variable so modules can be imported 
# end setting of home path variable and adding data directory to path import list

##############################################################################################################################################################################################################################

# begin import of created modules
try:   
    import ds
    import mypath
    input('''Success!!!

Press any key to exit...''')
except ModuleNotFoundError:
    input('''Before this program can be run, sani.py must be run first.
This will ensure that the needed python modules are created in the data directory!

Please run sani.py and try again

Press any key to exit...''')
# begin import of created modules

##############################################################################################################################################################################################################################
# Out:
# Success!!!
#
# Press any key to exit...y

# %%
# begin importing and creation of a data frame
df = pd.DataFrame(ds.dictStd.items())
df.rename(columns={0: "std", 1: "hsh"}, inplace = True)
# end importing and creation of a data frame

##############################################################################################################################################################################################################################

# begin vreation of the drivers path column in dataDrame
df['DriversPath'] = 'NaN'
# end vreation of the drivers path column in dataDrame

##############################################################################################################################################################################################################################

# %%
validHash = re.compile(r'#\d{0,3}')

# %%
def findDriver(pathOfFile):
    import ipdb; ipdb.set_trace()
    os.chdir(pathOfFile)
    if 'Drivers' in os.listdir():
        df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
        os.chdir(mypath.repos)
    else:
        for i in os.listdir():
            if os.path.isdir(i):
                pathOfFile = os.path.join(os.getcwd() ,  str(i))
                findDriver(pathOfFile)
            else:
                os.chdir(mypath.repos)

# %%
os.chdir(mypath.repos)
os.getcwd()
os.listdir()
findDriver(mypath.repos)
# Out:
# > <ipython-input-4-29ff16e312b3>(3)findDriver()
#       2     import ipdb; ipdb.set_trace()
# ----> 3     os.chdir(pathOfFile)
#       4     if 'Drivers' in os.listdir():
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(4)findDriver()
#       3     os.chdir(pathOfFile)
# ----> 4     if 'Drivers' in os.listdir():
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(10)findDriver()
#       9             if os.path.isdir(i):
# ---> 10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#      11                 findDriver(pathOfFile)
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(11)findDriver()
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
# ---> 11                 findDriver(pathOfFile)
#      12             else:
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(3)findDriver()
#       2     import ipdb; ipdb.set_trace()
# ----> 3     os.chdir(pathOfFile)
#       4     if 'Drivers' in os.listdir():
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(4)findDriver()
#       3     os.chdir(pathOfFile)
# ----> 4     if 'Drivers' in os.listdir():
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#
# ipdb> df
#         std hsh DriversPath
# 0  20416318  #6         NaN
# 1  21957029  #2         NaN
# 2  22046364  #0         NaN
# 3  22074376  #4         NaN
# 4  22127011  #3         NaN
# 5  22218521  #5         NaN
# 6  22252975  #1         NaN
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(5)findDriver()
#       4     if 'Drivers' in os.listdir():
# ----> 5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#       6         os.chdir(mypath.repos)
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(6)findDriver()
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
# ----> 6         os.chdir(mypath.repos)
#       7     else:
#
# ipdb> n
# --Return--
# None
# > <ipython-input-4-29ff16e312b3>(6)findDriver()
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
# ----> 6         os.chdir(mypath.repos)
#       7     else:
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1                                              NaN
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(10)findDriver()
#       9             if os.path.isdir(i):
# ---> 10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#      11                 findDriver(pathOfFile)
#
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1                                              NaN
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(11)findDriver()
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
# ---> 11                 findDriver(pathOfFile)
#      12             else:
#
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1                                              NaN
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(3)findDriver()
#       2     import ipdb; ipdb.set_trace()
# ----> 3     os.chdir(pathOfFile)
#       4     if 'Drivers' in os.listdir():
#
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1                                              NaN
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(4)findDriver()
#       3     os.chdir(pathOfFile)
# ----> 4     if 'Drivers' in os.listdir():
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1                                              NaN
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(5)findDriver()
#       4     if 'Drivers' in os.listdir():
# ----> 5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#       6         os.chdir(mypath.repos)
#
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1                                              NaN
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(6)findDriver()
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
# ----> 6         os.chdir(mypath.repos)
#       7     else:
#
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1
# ipdb> n
# --Return--
# None
# > <ipython-input-4-29ff16e312b3>(6)findDriver()
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
# ----> 6         os.chdir(mypath.repos)
#       7     else:
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> i
# '#1'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(10)findDriver()
#       9             if os.path.isdir(i):
# ---> 10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#      11                 findDriver(pathOfFile)
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(11)findDriver()
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
# ---> 11                 findDriver(pathOfFile)
#      12             else:
#
# ipdb> i
# '#2'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(3)findDriver()
#       2     import ipdb; ipdb.set_trace()
# ----> 3     os.chdir(pathOfFile)
#       4     if 'Drivers' in os.listdir():
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(4)findDriver()
#       3     os.chdir(pathOfFile)
# ----> 4     if 'Drivers' in os.listdir():
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#
# ipdb> i
# *** NameError: name 'i' is not defined
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> i
# *** NameError: name 'i' is not defined
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> i
# '21957029.txt'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(13)findDriver()
#      11                 findDriver(pathOfFile)
#      12             else:
# ---> 13                 os.chdir(mypath.repos)
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> i
# '21957029.txt'
# ipdb> n
# --Return--
# None
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> i
# '21957029.txt'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> i
# '#2'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> i
# '#3'
# ipdb> df
#         std hsh                                      DriversPath
# 0  20416318  #6                                              NaN
# 1  21957029  #2                                              NaN
# 2  22046364  #0  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#0
# 3  22074376  #4                                              NaN
# 4  22127011  #3                                              NaN
# 5  22218521  #5                                              NaN
# 6  22252975  #1  C:\Users\1995m\Desktop\skripsieCode\stdRepos\#1
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(10)findDriver()
#       9             if os.path.isdir(i):
# ---> 10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#      11                 findDriver(pathOfFile)
#
# ipdb> i
# '#3'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(11)findDriver()
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
# ---> 11                 findDriver(pathOfFile)
#      12             else:
#
# ipdb> pathOfFile
# 'C:\\Users\\1995m\\Desktop\\skripsieCode\\stdRepos\\#3'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(3)findDriver()
#       2     import ipdb; ipdb.set_trace()
# ----> 3     os.chdir(pathOfFile)
#       4     if 'Drivers' in os.listdir():
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(4)findDriver()
#       3     os.chdir(pathOfFile)
# ----> 4     if 'Drivers' in os.listdir():
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#
# ipdb> i
# *** NameError: name 'i' is not defined
# ipdb> os.getcwd()
# 'C:\\Users\\1995m\\Desktop\\skripsieCode\\stdRepos\\#3'
# ipdb> pathOfFile
# 'C:\\Users\\1995m\\Desktop\\skripsieCode\\stdRepos\\#3'
# ipdb> os.listdir()
# ['.git', '22127011.txt', 'First_Project', 'README.md']
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> i
# '.git'
# ipdb> os.path.isdir(i)
# True
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(10)findDriver()
#       9             if os.path.isdir(i):
# ---> 10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#      11                 findDriver(pathOfFile)
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(11)findDriver()
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
# ---> 11                 findDriver(pathOfFile)
#      12             else:
# ipdb> pathOfFile
# 'C:\\Users\\1995m\\Desktop\\skripsieCode\\stdRepos\\#3\\.git'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(3)findDriver()
#       2     import ipdb; ipdb.set_trace()
# ----> 3     os.chdir(pathOfFile)
#       4     if 'Drivers' in os.listdir():
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(4)findDriver()
#       3     os.chdir(pathOfFile)
# ----> 4     if 'Drivers' in os.listdir():
#       5         df.loc[df['hsh'] == validHash.findall(os.getcwd())[0], ['DriversPath']] = os.path.join(os.getcwd(), pathOfFile)
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> i
# 'config'
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(13)findDriver()
#      11                 findDriver(pathOfFile)
#      12             else:
# ---> 13                 os.chdir(mypath.repos)
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(8)findDriver()
#       7     else:
# ----> 8         for i in os.listdir():
#       9             if os.path.isdir(i):
#
# ipdb> n
# > <ipython-input-4-29ff16e312b3>(9)findDriver()
#       8         for i in os.listdir():
# ----> 9             if os.path.isdir(i):
#      10                 pathOfFile = os.path.join(os.getcwd() ,  str(i))
#
# ipdb> i
# 'description'

# %%
# for i in range(6):
#     import ipdb; ipdb.set_trace()
#     print(i)

# %%
# os.chdir(os.path.join(mypath.repos , str('#1')))
# for i in os.listdir():
#     if os.path.isdir(i):
#         print('yes')
# os.listdir()

# %%
type(mypath.repos)

# %%
pathOfFile

# %%
df.loc[df['hsh'] == validHash.findall(os.getcwd())[0]]

# %%
validHash.findall(os.getcwd())[0]

# %%
df
